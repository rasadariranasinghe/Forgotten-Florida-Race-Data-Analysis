# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from geopy.exc import GeocoderTimedOut

# %%
df = pd.read_csv('ff_race_50.csv')

# %%
df.head()
# Out:
#    Place    First     Last              City State  Age Division     Time  \
# 0      1   Daniel   Wilson             Tulsa    OK   35        M  8:23:01
# 1      2     Eric    Davis         Greenwood    IN   38        M  8:57:54
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M  9:24:35
# 3      4      Ron  Hammett         Montverde    FL   53        M  9:24:36
# 4      5     Seth     Cain            Geneva    FL   44        M  9:42:17
#
#   Unnamed: 8
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4

# %%
cleaned_df = df.dropna(axis = 1)

# %%
cleaned_df.head()
# Out:
#    Place    First     Last              City State  Age Division     Time
# 0      1   Daniel   Wilson             Tulsa    OK   35        M  8:23:01
# 1      2     Eric    Davis         Greenwood    IN   38        M  8:57:54
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M  9:24:35
# 3      4      Ron  Hammett         Montverde    FL   53        M  9:24:36
# 4      5     Seth     Cain            Geneva    FL   44        M  9:42:17

# %%
cleaned_df['FullName'] = cleaned_df['First'] + ' ' + cleaned_df['Last']

# %%
cleaned_df.head()
# Out:
#    Place    First     Last              City State  Age Division     Time  \
# 0      1   Daniel   Wilson             Tulsa    OK   35        M  8:23:01
# 1      2     Eric    Davis         Greenwood    IN   38        M  8:57:54
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M  9:24:35
# 3      4      Ron  Hammett         Montverde    FL   53        M  9:24:36
# 4      5     Seth     Cain            Geneva    FL   44        M  9:42:17
#
#           FullName
# 0    Daniel Wilson
# 1       Eric Davis
# 2  Stewart Edwards
# 3      Ron Hammett
# 4        Seth Cain

# %%
 cleaned_df['Time'] = pd.to_timedelta(cleaned_df['Time'])

# %%
cleaned_df['Totalminutes'] = (cleaned_df['Time'].dt.total_seconds() / 60).round(2)

# %%
cleaned_df.head()
# Out:
#    Place    First     Last              City State  Age Division  \
# 0      1   Daniel   Wilson             Tulsa    OK   35        M
# 1      2     Eric    Davis         Greenwood    IN   38        M
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M
# 3      4      Ron  Hammett         Montverde    FL   53        M
# 4      5     Seth     Cain            Geneva    FL   44        M
#
#              Time         FullName  Totalminutes
# 0 0 days 08:23:01    Daniel Wilson        503.02
# 1 0 days 08:57:54       Eric Davis        537.90
# 2 0 days 09:24:35  Stewart Edwards        564.58
# 3 0 days 09:24:36      Ron Hammett        564.60
# 4 0 days 09:42:17        Seth Cain        582.28

# %%
cleaned_df.dtypes
# Out:
# Place                     int64
# First                    object
# Last                     object
# City                     object
# State                    object
# Age                       int64
# Division                 object
# Time            timedelta64[ns]
# FullName                 object
# Totalminutes            float64
# dtype: object

# %%
cleaned_df.rename(columns = {'Division' : 'Gender'}, inplace = True)

# %%
def get_lat_long(city, state):
  address = f'{city}, {state}'
  try:
        geolocator = Nominatim(user_agent = 'my_request',timeout=10)
        location = geolocator.geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
  except GeocoderTimedOut:
        return None, None

# %%
cleaned_df['Latitude'], cleaned_df['Longitude'] = zip(*cleaned_df.apply(lambda row: get_lat_long(row['City'], row['State']), axis=1))

# %%
cleaned_df.head()
# Out:
#    Place    First     Last              City State  Age Gender  \
# 0      1   Daniel   Wilson             Tulsa    OK   35      M
# 1      2     Eric    Davis         Greenwood    IN   38      M
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43      M
# 3      4      Ron  Hammett         Montverde    FL   53      M
# 4      5     Seth     Cain            Geneva    FL   44      M
#
#              Time         FullName  Totalminutes   Latitude  Longitude
# 0 0 days 08:23:01    Daniel Wilson        503.02  36.156312 -95.992752
# 1 0 days 08:57:54       Eric Davis        537.90  39.613699 -86.109543
# 2 0 days 09:24:35  Stewart Edwards        564.58  29.025813 -80.927127
# 3 0 days 09:24:36      Ron Hammett        564.60  28.600277 -81.673964
# 4 0 days 09:42:17        Seth Cain        582.28  28.737294 -81.113420

# %%
cleaned_df['Coordinates'] = cleaned_df['Latitude'].astype(str) + ', ' + cleaned_df['Longitude'].astype(str)
cleaned_df.drop(columns=['Latitude','Longitude'])
# Out:
#     Place     First      Last              City State  Age Gender  \
# 0       1    Daniel    Wilson             Tulsa    OK   35      M
# 1       2      Eric     Davis         Greenwood    IN   38      M
# 2       3   Stewart   Edwards  New Smyrna Beach    FL   43      M
# 3       4       Ron   Hammett         Montverde    FL   53      M
# 4       5      Seth      Cain            Geneva    FL   44      M
# ..    ...       ...       ...               ...   ...  ...    ...
# 91     92      Ryan     Nolan           Orlando    FL   26      M
# 92     93  Brittany  Sobering    Winter Springs    FL   41      F
# 93     94    Gordon     Bloom          St Cloud    FL   53      M
# 94     95       Jen      Maki       Casselberry    FL   41      F
# 95     96      Nick   Collins        Plant City    FL   42      M
#
#               Time           FullName  Totalminutes  \
# 0  0 days 08:23:01      Daniel Wilson        503.02
# 1  0 days 08:57:54         Eric Davis        537.90
# 2  0 days 09:24:35    Stewart Edwards        564.58
# 3  0 days 09:24:36        Ron Hammett        564.60
# 4  0 days 09:42:17          Seth Cain        582.28
# ..             ...                ...           ...
# 91 0 days 14:26:47         Ryan Nolan        866.78
# 92 0 days 14:29:08  Brittany Sobering        869.13
# 93 0 days 14:29:23       Gordon Bloom        869.38
# 94 0 days 14:29:30           Jen Maki        869.50
# 95 0 days 14:29:54       Nick Collins        869.90
#
#                       Coordinates
# 0         36.1563122, -95.9927516
# 1         39.6136987, -86.1095429
# 2         29.0258132, -80.9271271
# 3          28.6002769, -81.673964
# 4   28.737294, -81.11342048773265
# ..                            ...
# 91        28.5421109, -81.3790304
# 92        28.6987317, -81.3055188
# 93        28.2498534, -81.2839038
# 94        28.6714702, -81.3382005
# 95          28.01633, -82.1234803
#
# [96 rows x 11 columns]

# %%
cleaned_df.head()
# Out:
#    Place    First     Last              City State  Age Gender  \
# 0      1   Daniel   Wilson             Tulsa    OK   35      M
# 1      2     Eric    Davis         Greenwood    IN   38      M
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43      M
# 3      4      Ron  Hammett         Montverde    FL   53      M
# 4      5     Seth     Cain            Geneva    FL   44      M
#
#              Time         FullName  Totalminutes   Latitude  Longitude  \
# 0 0 days 08:23:01    Daniel Wilson        503.02  36.156312 -95.992752
# 1 0 days 08:57:54       Eric Davis        537.90  39.613699 -86.109543
# 2 0 days 09:24:35  Stewart Edwards        564.58  29.025813 -80.927127
# 3 0 days 09:24:36      Ron Hammett        564.60  28.600277 -81.673964
# 4 0 days 09:42:17        Seth Cain        582.28  28.737294 -81.113420
#
#                      Coordinates
# 0        36.1563122, -95.9927516
# 1        39.6136987, -86.1095429
# 2        29.0258132, -80.9271271
# 3         28.6002769, -81.673964
# 4  28.737294, -81.11342048773265

# %%
cleaned_df.to_csv('cleaned_ff_race_50.csv', index=False)

# %%
cleaned_df.dtypes
# Out:
# Place                     int64
# First                    object
# Last                     object
# City                     object
# State                    object
# Age                       int64
# Gender                   object
# Time            timedelta64[ns]
# FullName                 object
# Totalminutes            float64
# Latitude                float64
# Longitude               float64
# Coordinates              object
# dtype: object
